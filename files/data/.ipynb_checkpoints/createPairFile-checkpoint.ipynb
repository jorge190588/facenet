# %%
import os
import random

def createPairs(totalPairs):
    result = []
    for i in range(0, totalPairs-1):
        for y in range(i+1, totalPairs):
            #print str(i)+'-'+str(y)
            result.append([i,y])
    
    return result

def getFolders(baseDir):
    folders = [name for name in os.listdir(baseDir) if name.find(".txt") == -1]  
    return sorted(folders, reverse=False)

baseDir = "/notebooks/lfw/output/"
separate = "_0"
folders = getFolders(baseDir)
filePath = "/notebooks/data/pairs30.txt"

def pairs():
    for name in folders:    
        path, dirs, files = next(os.walk(baseDir+name))
        file_count = len(files)
        if file_count>30:
            file_count=30
            
        if(file_count>0):
            a = []
            for file in os.listdir(baseDir + name):
                a.append(file)

            with open(filePath,"a") as f:
                pair_two_list = createPairs(file_count)
                randomChoice = random.choice(a)
                temp = random.choice(a).split(separate)[0] # This line may vary depending on how your images are named.
                print('name',name,'count',file_count,'randomChoice',randomChoice,'temp',temp)
                for l1 in pair_two_list:
                    n0 = a[l1[0]].split(separate)[1].lstrip("0").rstrip(".png")
                    n1 = a[l1[1]].split(separate)[1].lstrip("0").rstrip(".png")
                    content = temp + "\t" + n0 + "\t" + n1 + "\n"
                    f.write(content)

def shuffle(): 
    for i,name in enumerate(folders):
        remaining = folders

        del remaining[i] # deletes the file from the list, so that it is not chosen again
        other_dir = random.choice(remaining)

        with open(filePath,"a") as f:
            flag=1
            for i in range(1):
                file1 = random.choice(os.listdir(baseDir + name))
                file2 = random.choice(os.listdir(baseDir+ other_dir))
                content = name + "\t" + file1.split(separate)[1].lstrip("0").rstrip(".png") + "\t" + other_dir + "\t" + file2.split(separate)[1].lstrip("0").rstrip(".png") + "\n"
                f.write(content)

# %%
pairs()
shuffle()
# Out:
# ('name', 'Camila_Santos', 'count', 30, 'randomChoice', 'Camila_Santos_0336.png', 'temp', 'Camila_Santos')
# ('content', 'Camila_Santos\t915\t755\n')
# ('content', 'Camila_Santos\t915\t748\n')
# ('content', 'Camila_Santos\t915\t970\n')
# ('content', 'Camila_Santos\t915\t405\n')
# ('content', 'Camila_Santos\t915\t380\n')
# ('content', 'Camila_Santos\t915\t772\n')
# ('content', 'Camila_Santos\t915\t714\n')
# ('content', 'Camila_Santos\t915\t809\n')
# ('content', 'Camila_Santos\t915\t736\n')
# ('content', 'Camila_Santos\t915\t386\n')
# ('content', 'Camila_Santos\t915\t221\n')
# ('content', 'Camila_Santos\t915\t458\n')
# ('content', 'Camila_Santos\t915\t485\n')
# ('content', 'Camila_Santos\t915\t209\n')
# ('content', 'Camila_Santos\t915\t73\n')
# ('content', 'Camila_Santos\t915\t554\n')
# ('content', 'Camila_Santos\t915\t673\n')
# ('content', 'Camila_Santos\t915\t55\n')
# ('content', 'Camila_Santos\t915\t444\n')
# ('content', 'Camila_Santos\t915\t337\n')
# ('content', 'Camila_Santos\t915\t279\n')
# ('content', 'Camila_Santos\t915\t497\n')
# ('content', 'Camila_Santos\t915\t486\n')
# ('content', 'Camila_Santos\t915\t76\n')
# ('content', 'Camila_Santos\t915\t481\n')
# ('content', 'Camila_Santos\t915\t349\n')
# ('content', 'Camila_Santos\t915\t143\n')
# ('content', 'Camila_Santos\t915\t294\n')
# ('content', 'Camila_Santos\t915\t122\n')
# ('content', 'Camila_Santos\t755\t748\n')
# ('content', 'Camila_Santos\t755\t970\n')
# ('content', 'Camila_Santos\t755\t405\n')
# ('content', 'Camila_Santos\t755\t380\n')
# ('content', 'Camila_Santos\t755\t772\n')
# ('content', 'Camila_Santos\t755\t714\n')
# ('content', 'Camila_Santos\t755\t809\n')
# ('content', 'Camila_Santos\t755\t736\n')
# ('content', 'Camila_Santos\t755\t386\n')
# ('content', 'Camila_Santos\t755\t221\n')
# ('content', 'Camila_Santos\t755\t458\n')
# ('content', 'Camila_Santos\t755\t485\n')
# ('content', 'Camila_Santos\t755\t209\n')
# ('content', 'Camila_Santos\t755\t73\n')
# ('content', 'Camila_Santos\t755\t554\n')
# ('content', 'Camila_Santos\t755\t673\n')
# ('content', 'Camila_Santos\t755\t55\n')
# ('content', 'Camila_Santos\t755\t444\n')
# ('content', 'Camila_Santos\t755\t337\n')
# ('content', 'Camila_Santos\t755\t279\n')
# ('content', 'Camila_Santos\t755\t497\n')
# ('content', 'Camila_Santos\t755\t486\n')
# ('content', 'Camila_Santos\t755\t76\n')
# ('content', 'Camila_Santos\t755\t481\n')
# ('content', 'Camila_Santos\t755\t349\n')
# ('content', 'Camila_Santos\t755\t143\n')
# ('content', 'Camila_Santos\t755\t294\n')
# ('content', 'Camila_Santos\t755\t122\n')
# ('content', 'Camila_Santos\t748\t970\n')
# ('content', 'Camila_Santos\t748\t405\n')
# ('content', 'Camila_Santos\t748\t380\n')
# ('content', 'Camila_Santos\t748\t772\n')
# ('content', 'Camila_Santos\t748\t714\n')
# ('content', 'Camila_Santos\t748\t809\n')
# ('content', 'Camila_Santos\t748\t736\n')
# ('content', 'Camila_Santos\t748\t386\n')
# ('content', 'Camila_Santos\t748\t221\n')
# ('content', 'Camila_Santos\t748\t458\n')
# ('content', 'Camila_Santos\t748\t485\n')
# ('content', 'Camila_Santos\t748\t209\n')
# ('content', 'Camila_Santos\t748\t73\n')
# ('content', 'Camila_Santos\t748\t554\n')
# ('content', 'Camila_Santos\t748\t673\n')
# ('content', 'Camila_Santos\t748\t55\n')
# ('content', 'Camila_Santos\t748\t444\n')
# ('content', 'Camila_Santos\t748\t337\n')
# ('content', 'Camila_Santos\t748\t279\n')
# ('content', 'Camila_Santos\t748\t497\n')
# ('content', 'Camila_Santos\t748\t486\n')
# ('content', 'Camila_Santos\t748\t76\n')
# ('content', 'Camila_Santos\t748\t481\n')
# ('content', 'Camila_Santos\t748\t349\n')
# ('content', 'Camila_Santos\t748\t143\n')
# ('content', 'Camila_Santos\t748\t294\n')
# ('content', 'Camila_Santos\t748\t122\n')
# ('content', 'Camila_Santos\t970\t405\n')
# ('content', 'Camila_Santos\t970\t380\n')
# ('content', 'Camila_Santos\t970\t772\n')
# ('content', 'Camila_Santos\t970\t714\n')
# ('content', 'Camila_Santos\t970\t809\n')
# ('content', 'Camila_Santos\t970\t736\n')
# ('content', 'Camila_Santos\t970\t386\n')
# ('content', 'Camila_Santos\t970\t221\n')
# ('content', 'Camila_Santos\t970\t458\n')
# ('content', 'Camila_Santos\t970\t485\n')
# ('content', 'Camila_Santos\t970\t209\n')
# ('content', 'Camila_Santos\t970\t73\n')
# ('content', 'Camila_Santos\t970\t554\n')
# ('content', 'Camila_Santos\t970\t673\n')
# ('content', 'Camila_Santos\t970\t55\n')
# ('content', 'Camila_Santos\t970\t444\n')
# ('content', 'Camila_Santos\t970\t337\n')
# ('content', 'Camila_Santos\t970\t279\n')
# ('content', 'Camila_Santos\t970\t497\n')
# ('content', 'Camila_Santos\t970\t486\n')
# ('content', 'Camila_Santos\t970\t76\n')
# ('content', 'Camila_Santos\t970\t481\n')
# ('content', 'Camila_Santos\t970\t349\n')
# ('content', 'Camila_Santos\t970\t143\n')
# ('content', 'Camila_Santos\t970\t294\n')
# ('content', 'Camila_Santos\t970\t122\n')
# ('content', 'Camila_Santos\t405\t380\n')
# ('content', 'Camila_Santos\t405\t772\n')
# ('content', 'Camila_Santos\t405\t714\n')
# ('content', 'Camila_Santos\t405\t809\n')
# ('content', 'Camila_Santos\t405\t736\n')
# ('content', 'Camila_Santos\t405\t386\n')
# ('content', 'Camila_Santos\t405\t221\n')
# ('content', 'Camila_Santos\t405\t458\n')
# ('content', 'Camila_Santos\t405\t485\n')
# ('content', 'Camila_Santos\t405\t209\n')
# ('content', 'Camila_Santos\t405\t73\n')
# ('content', 'Camila_Santos\t405\t554\n')
# ('content', 'Camila_Santos\t405\t673\n')
# ('content', 'Camila_Santos\t405\t55\n')
# ('content', 'Camila_Santos\t405\t444\n')
# ('content', 'Camila_Santos\t405\t337\n')
# ('content', 'Camila_Santos\t405\t279\n')
# ('content', 'Camila_Santos\t405\t497\n')
# ('content', 'Camila_Santos\t405\t486\n')
# ('content', 'Camila_Santos\t405\t76\n')
# ('content', 'Camila_Santos\t405\t481\n')
# ('content', 'Camila_Santos\t405\t349\n')
# ('content', 'Camila_Santos\t405\t143\n')
# ('content', 'Camila_Santos\t405\t294\n')
# ('content', 'Camila_Santos\t405\t122\n')
# ('content', 'Camila_Santos\t380\t772\n')
# ('content', 'Camila_Santos\t380\t714\n')
# ('content', 'Camila_Santos\t380\t809\n')
# ('content', 'Camila_Santos\t380\t736\n')
# ('content', 'Camila_Santos\t380\t386\n')
# ('content', 'Camila_Santos\t380\t221\n')
# ('content', 'Camila_Santos\t380\t458\n')
# ('content', 'Camila_Santos\t380\t485\n')
# ('content', 'Camila_Santos\t380\t209\n')
# ('content', 'Camila_Santos\t380\t73\n')
# ('content', 'Camila_Santos\t380\t554\n')
# ('content', 'Camila_Santos\t380\t673\n')
# ('content', 'Camila_Santos\t380\t55\n')
# ('content', 'Camila_Santos\t380\t444\n')
# ('content', 'Camila_Santos\t380\t337\n')
# ('content', 'Camila_Santos\t380\t279\n')
# ('content', 'Camila_Santos\t380\t497\n')
# ('content', 'Camila_Santos\t380\t486\n')
# ('content', 'Camila_Santos\t380\t76\n')
# ('content', 'Camila_Santos\t380\t481\n')
# ('content', 'Camila_Santos\t380\t349\n')
# ('content', 'Camila_Santos\t380\t143\n')
# ('content', 'Camila_Santos\t380\t294\n')
# ('content', 'Camila_Santos\t380\t122\n')
# ('content', 'Camila_Santos\t772\t714\n')
# ('content', 'Camila_Santos\t772\t809\n')
# ('content', 'Camila_Santos\t772\t736\n')
# ('content', 'Camila_Santos\t772\t386\n')
# ('content', 'Camila_Santos\t772\t221\n')
# ('content', 'Camila_Santos\t772\t458\n')
# ('content', 'Camila_Santos\t772\t485\n')
# ('content', 'Camila_Santos\t772\t209\n')
# ('content', 'Camila_Santos\t772\t73\n')
# ('content', 'Camila_Santos\t772\t554\n')
# ('content', 'Camila_Santos\t772\t673\n')
# ('content', 'Camila_Santos\t772\t55\n')
# ('content', 'Camila_Santos\t772\t444\n')
# ('content', 'Camila_Santos\t772\t337\n')
# ('content', 'Camila_Santos\t772\t279\n')
# ('content', 'Camila_Santos\t772\t497\n')
# ('content', 'Camila_Santos\t772\t486\n')
# ('content', 'Camila_Santos\t772\t76\n')
# ('content', 'Camila_Santos\t772\t481\n')
# ('content', 'Camila_Santos\t772\t349\n')
# ('content', 'Camila_Santos\t772\t143\n')
# ('content', 'Camila_Santos\t772\t294\n')
# ('content', 'Camila_Santos\t772\t122\n')
# ('content', 'Camila_Santos\t714\t809\n')
# ('content', 'Camila_Santos\t714\t736\n')
# ('content', 'Camila_Santos\t714\t386\n')
# ('content', 'Camila_Santos\t714\t221\n')
# ('content', 'Camila_Santos\t714\t458\n')
# ('content', 'Camila_Santos\t714\t485\n')
# ('content', 'Camila_Santos\t714\t209\n')
# ('content', 'Camila_Santos\t714\t73\n')
# ('content', 'Camila_Santos\t714\t554\n')
# ('content', 'Camila_Santos\t714\t673\n')
# ('content', 'Camila_Santos\t714\t55\n')
# ('content', 'Camila_Santos\t714\t444\n')
# ('content', 'Camila_Santos\t714\t337\n')
# ('content', 'Camila_Santos\t714\t279\n')
# ('content', 'Camila_Santos\t714\t497\n')
# ('content', 'Camila_Santos\t714\t486\n')
# ('content', 'Camila_Santos\t714\t76\n')
# ('content', 'Camila_Santos\t714\t481\n')
# ('content', 'Camila_Santos\t714\t349\n')
# ('content', 'Camila_Santos\t714\t143\n')
# ('content', 'Camila_Santos\t714\t294\n')
# ('content', 'Camila_Santos\t714\t122\n')
# ('content', 'Camila_Santos\t809\t736\n')
# ('content', 'Camila_Santos\t809\t386\n')
# ('content', 'Camila_Santos\t809\t221\n')
# ('content', 'Camila_Santos\t809\t458\n')
# ('content', 'Camila_Santos\t809\t485\n')
# ('content', 'Camila_Santos\t809\t209\n')
# ('content', 'Camila_Santos\t809\t73\n')
# ('content', 'Camila_Santos\t809\t554\n')
# ('content', 'Camila_Santos\t809\t673\n')
# ('content', 'Camila_Santos\t809\t55\n')
# ('content', 'Camila_Santos\t809\t444\n')
# ('content', 'Camila_Santos\t809\t337\n')
# ('content', 'Camila_Santos\t809\t279\n')
# ('content', 'Camila_Santos\t809\t497\n')
# ('content', 'Camila_Santos\t809\t486\n')
# ('content', 'Camila_Santos\t809\t76\n')
# ('content', 'Camila_Santos\t809\t481\n')
# ('content', 'Camila_Santos\t809\t349\n')
# ('content', 'Camila_Santos\t809\t143\n')
# ('content', 'Camila_Santos\t809\t294\n')
# ('content', 'Camila_Santos\t809\t122\n')
# ('content', 'Camila_Santos\t736\t386\n')
# ('content', 'Camila_Santos\t736\t221\n')
# ('content', 'Camila_Santos\t736\t458\n')
# ('content', 'Camila_Santos\t736\t485\n')
# ('content', 'Camila_Santos\t736\t209\n')
# ('content', 'Camila_Santos\t736\t73\n')
# ('content', 'Camila_Santos\t736\t554\n')
# ('content', 'Camila_Santos\t736\t673\n')
# ('content', 'Camila_Santos\t736\t55\n')
# ('content', 'Camila_Santos\t736\t444\n')
# ('content', 'Camila_Santos\t736\t337\n')
# ('content', 'Camila_Santos\t736\t279\n')
# ('content', 'Camila_Santos\t736\t497\n')
# ('content', 'Camila_Santos\t736\t486\n')
# ('content', 'Camila_Santos\t736\t76\n')
# ('content', 'Camila_Santos\t736\t481\n')
# ('content', 'Camila_Santos\t736\t349\n')
# ('content', 'Camila_Santos\t736\t143\n')
# ('content', 'Camila_Santos\t736\t294\n')
# ('content', 'Camila_Santos\t736\t122\n')
# ('content', 'Camila_Santos\t386\t221\n')
# ('content', 'Camila_Santos\t386\t458\n')
# ('content', 'Camila_Santos\t386\t485\n')
# ('content', 'Camila_Santos\t386\t209\n')
# ('content', 'Camila_Santos\t386\t73\n')
# ('content', 'Camila_Santos\t386\t554\n')
# ('content', 'Camila_Santos\t386\t673\n')
# ('content', 'Camila_Santos\t386\t55\n')
# ('content', 'Camila_Santos\t386\t444\n')
# ('content', 'Camila_Santos\t386\t337\n')
# ('content', 'Camila_Santos\t386\t279\n')
# ('content', 'Camila_Santos\t386\t497\n')
# ('content', 'Camila_Santos\t386\t486\n')
# ('content', 'Camila_Santos\t386\t76\n')
# ('content', 'Camila_Santos\t386\t481\n')
# ('content', 'Camila_Santos\t386\t349\n')
# ('content', 'Camila_Santos\t386\t143\n')
# ('content', 'Camila_Santos\t386\t294\n')
# ('content', 'Camila_Santos\t386\t122\n')
# ('content', 'Camila_Santos\t221\t458\n')
# ('content', 'Camila_Santos\t221\t485\n')
# ('content', 'Camila_Santos\t221\t209\n')
# ('content', 'Camila_Santos\t221\t73\n')
# ('content', 'Camila_Santos\t221\t554\n')
# ('content', 'Camila_Santos\t221\t673\n')
# ('content', 'Camila_Santos\t221\t55\n')
# ('content', 'Camila_Santos\t221\t444\n')
# ('content', 'Camila_Santos\t221\t337\n')
# ('content', 'Camila_Santos\t221\t279\n')
# ('content', 'Camila_Santos\t221\t497\n')
# ('content', 'Camila_Santos\t221\t486\n')
# ('content', 'Camila_Santos\t221\t76\n')
# ('content', 'Camila_Santos\t221\t481\n')
# ('content', 'Camila_Santos\t221\t349\n')
# ('content', 'Camila_Santos\t221\t143\n')
# ('content', 'Camila_Santos\t221\t294\n')
# ('content', 'Camila_Santos\t221\t122\n')
# ('content', 'Camila_Santos\t458\t485\n')
# ('content', 'Camila_Santos\t458\t209\n')
# ('content', 'Camila_Santos\t458\t73\n')
# ('content', 'Camila_Santos\t458\t554\n')
# ('content', 'Camila_Santos\t458\t673\n')
# ('content', 'Camila_Santos\t458\t55\n')
# ('content', 'Camila_Santos\t458\t444\n')
# ('content', 'Camila_Santos\t458\t337\n')
# ('content', 'Camila_Santos\t458\t279\n')
# ('content', 'Camila_Santos\t458\t497\n')
# ('content', 'Camila_Santos\t458\t486\n')
# ('content', 'Camila_Santos\t458\t76\n')
# ('content', 'Camila_Santos\t458\t481\n')
# ('content', 'Camila_Santos\t458\t349\n')
# ('content', 'Camila_Santos\t458\t143\n')
# ('content', 'Camila_Santos\t458\t294\n')
# ('content', 'Camila_Santos\t458\t122\n')
# ('content', 'Camila_Santos\t485\t209\n')
# ('content', 'Camila_Santos\t485\t73\n')
# ('content', 'Camila_Santos\t485\t554\n')
# ('content', 'Camila_Santos\t485\t673\n')
# ('content', 'Camila_Santos\t485\t55\n')
# ('content', 'Camila_Santos\t485\t444\n')
# ('content', 'Camila_Santos\t485\t337\n')
# ('content', 'Camila_Santos\t485\t279\n')
# ('content', 'Camila_Santos\t485\t497\n')
# ('content', 'Camila_Santos\t485\t486\n')
# ('content', 'Camila_Santos\t485\t76\n')
# ('content', 'Camila_Santos\t485\t481\n')
# ('content', 'Camila_Santos\t485\t349\n')
# ('content', 'Camila_Santos\t485\t143\n')
# ('content', 'Camila_Santos\t485\t294\n')
# ('content', 'Camila_Santos\t485\t122\n')
# ('content', 'Camila_Santos\t209\t73\n')
# ('content', 'Camila_Santos\t209\t554\n')
# ('content', 'Camila_Santos\t209\t673\n')
# ('content', 'Camila_Santos\t209\t55\n')
# ('content', 'Camila_Santos\t209\t444\n')
# ('content', 'Camila_Santos\t209\t337\n')
# ('content', 'Camila_Santos\t209\t279\n')
# ('content', 'Camila_Santos\t209\t497\n')
# ('content', 'Camila_Santos\t209\t486\n')
# ('content', 'Camila_Santos\t209\t76\n')
# ('content', 'Camila_Santos\t209\t481\n')
# ('content', 'Camila_Santos\t209\t349\n')
# ('content', 'Camila_Santos\t209\t143\n')
# ('content', 'Camila_Santos\t209\t294\n')
# ('content', 'Camila_Santos\t209\t122\n')
# ('content', 'Camila_Santos\t73\t554\n')
# ('content', 'Camila_Santos\t73\t673\n')
# ('content', 'Camila_Santos\t73\t55\n')
# ('content', 'Camila_Santos\t73\t444\n')
# ('content', 'Camila_Santos\t73\t337\n')
# ('content', 'Camila_Santos\t73\t279\n')
# ('content', 'Camila_Santos\t73\t497\n')
# ('content', 'Camila_Santos\t73\t486\n')
# ('content', 'Camila_Santos\t73\t76\n')
# ('content', 'Camila_Santos\t73\t481\n')
# ('content', 'Camila_Santos\t73\t349\n')
# ('content', 'Camila_Santos\t73\t143\n')
# ('content', 'Camila_Santos\t73\t294\n')
# ('content', 'Camila_Santos\t73\t122\n')
# ('content', 'Camila_Santos\t554\t673\n')
# ('content', 'Camila_Santos\t554\t55\n')
# ('content', 'Camila_Santos\t554\t444\n')
# ('content', 'Camila_Santos\t554\t337\n')
# ('content', 'Camila_Santos\t554\t279\n')
# ('content', 'Camila_Santos\t554\t497\n')
# ('content', 'Camila_Santos\t554\t486\n')
# ('content', 'Camila_Santos\t554\t76\n')
# ('content', 'Camila_Santos\t554\t481\n')
# ('content', 'Camila_Santos\t554\t349\n')
# ('content', 'Camila_Santos\t554\t143\n')
# ('content', 'Camila_Santos\t554\t294\n')
# ('content', 'Camila_Santos\t554\t122\n')
# ('content', 'Camila_Santos\t673\t55\n')
# ('content', 'Camila_Santos\t673\t444\n')
# ('content', 'Camila_Santos\t673\t337\n')
# ('content', 'Camila_Santos\t673\t279\n')
# ('content', 'Camila_Santos\t673\t497\n')
# ('content', 'Camila_Santos\t673\t486\n')
# ('content', 'Camila_Santos\t673\t76\n')
# ('content', 'Camila_Santos\t673\t481\n')
# ('content', 'Camila_Santos\t673\t349\n')
# ('content', 'Camila_Santos\t673\t143\n')
# ('content', 'Camila_Santos\t673\t294\n')
# ('content', 'Camila_Santos\t673\t122\n')
# ('content', 'Camila_Santos\t55\t444\n')
# ('content', 'Camila_Santos\t55\t337\n')
# ('content', 'Camila_Santos\t55\t279\n')
# ('content', 'Camila_Santos\t55\t497\n')
# ('content', 'Camila_Santos\t55\t486\n')
# ('content', 'Camila_Santos\t55\t76\n')
# ('content', 'Camila_Santos\t55\t481\n')
# ('content', 'Camila_Santos\t55\t349\n')
# ('content', 'Camila_Santos\t55\t143\n')
# ('content', 'Camila_Santos\t55\t294\n')
# ('content', 'Camila_Santos\t55\t122\n')
# ('content', 'Camila_Santos\t444\t337\n')
# ('content', 'Camila_Santos\t444\t279\n')
# ('content', 'Camila_Santos\t444\t497\n')
# ('content', 'Camila_Santos\t444\t486\n')
# ('content', 'Camila_Santos\t444\t76\n')
# ('content', 'Camila_Santos\t444\t481\n')
# ('content', 'Camila_Santos\t444\t349\n')
# ('content', 'Camila_Santos\t444\t143\n')
# ('content', 'Camila_Santos\t444\t294\n')
# ('content', 'Camila_Santos\t444\t122\n')
# ('content', 'Camila_Santos\t337\t279\n')
# ('content', 'Camila_Santos\t337\t497\n')
# ('content', 'Camila_Santos\t337\t486\n')
# ('content', 'Camila_Santos\t337\t76\n')
# ('content', 'Camila_Santos\t337\t481\n')
# ('content', 'Camila_Santos\t337\t349\n')
# ('content', 'Camila_Santos\t337\t143\n')
# ('content', 'Camila_Santos\t337\t294\n')
# ('content', 'Camila_Santos\t337\t122\n')
# ('content', 'Camila_Santos\t279\t497\n')
# ('content', 'Camila_Santos\t279\t486\n')
# ('content', 'Camila_Santos\t279\t76\n')
# ('content', 'Camila_Santos\t279\t481\n')
# ('content', 'Camila_Santos\t279\t349\n')
# ('content', 'Camila_Santos\t279\t143\n')
# ('content', 'Camila_Santos\t279\t294\n')
# ('content', 'Camila_Santos\t279\t122\n')
# ('content', 'Camila_Santos\t497\t486\n')
# ('content', 'Camila_Santos\t497\t76\n')
# ('content', 'Camila_Santos\t497\t481\n')
# ('content', 'Camila_Santos\t497\t349\n')
# ('content', 'Camila_Santos\t497\t143\n')
# ('content', 'Camila_Santos\t497\t294\n')
# ('content', 'Camila_Santos\t497\t122\n')
# ('content', 'Camila_Santos\t486\t76\n')
# ('content', 'Camila_Santos\t486\t481\n')
# ('content', 'Camila_Santos\t486\t349\n')
# ('content', 'Camila_Santos\t486\t143\n')
# ('content', 'Camila_Santos\t486\t294\n')
# ('content', 'Camila_Santos\t486\t122\n')
# ('content', 'Camila_Santos\t76\t481\n')
# ('content', 'Camila_Santos\t76\t349\n')
# ('content', 'Camila_Santos\t76\t143\n')
# ('content', 'Camila_Santos\t76\t294\n')
# ('content', 'Camila_Santos\t76\t122\n')
# ('content', 'Camila_Santos\t481\t349\n')
# ('content', 'Camila_Santos\t481\t143\n')
# ('content', 'Camila_Santos\t481\t294\n')
# ('content', 'Camila_Santos\t481\t122\n')
# ('content', 'Camila_Santos\t349\t143\n')
# ('content', 'Camila_Santos\t349\t294\n')
# ('content', 'Camila_Santos\t349\t122\n')
# ('content', 'Camila_Santos\t143\t294\n')
# ('content', 'Camila_Santos\t143\t122\n')
# ('content', 'Camila_Santos\t294\t122\n')
# ('name', 'Cristiano_Ronaldo', 'count', 16, 'randomChoice', 'Cristiano_Ronaldo_0009.png', 'temp', 'Cristiano_Ronaldo')
# ('content', 'Cristiano_Ronaldo\t7\t4\n')
# ('content', 'Cristiano_Ronaldo\t7\t14\n')
# ('content', 'Cristiano_Ronaldo\t7\t13\n')
# ('content', 'Cristiano_Ronaldo\t7\t5\n')
# ('content', 'Cristiano_Ronaldo\t7\t16\n')
# ('content', 'Cristiano_Ronaldo\t7\t2\n')
# ('content', 'Cristiano_Ronaldo\t7\t10\n')
# ('content', 'Cristiano_Ronaldo\t7\t8\n')
# ('content', 'Cristiano_Ronaldo\t7\t9\n')
# ('content', 'Cristiano_Ronaldo\t7\t15\n')
# ('content', 'Cristiano_Ronaldo\t7\t1\n')
# ('content', 'Cristiano_Ronaldo\t7\t6\n')
# ('content', 'Cristiano_Ronaldo\t7\t12\n')
# ('content', 'Cristiano_Ronaldo\t7\t3\n')
# ('content', 'Cristiano_Ronaldo\t7\t11\n')
# ('content', 'Cristiano_Ronaldo\t4\t14\n')
# ('content', 'Cristiano_Ronaldo\t4\t13\n')
# ('content', 'Cristiano_Ronaldo\t4\t5\n')
# ('content', 'Cristiano_Ronaldo\t4\t16\n')
# ('content', 'Cristiano_Ronaldo\t4\t2\n')
# ('content', 'Cristiano_Ronaldo\t4\t10\n')
# ('content', 'Cristiano_Ronaldo\t4\t8\n')
# ('content', 'Cristiano_Ronaldo\t4\t9\n')
# ('content', 'Cristiano_Ronaldo\t4\t15\n')
# ('content', 'Cristiano_Ronaldo\t4\t1\n')
# ('content', 'Cristiano_Ronaldo\t4\t6\n')
# ('content', 'Cristiano_Ronaldo\t4\t12\n')
# ('content', 'Cristiano_Ronaldo\t4\t3\n')
# ('content', 'Cristiano_Ronaldo\t4\t11\n')
# ('content', 'Cristiano_Ronaldo\t14\t13\n')
# ('content', 'Cristiano_Ronaldo\t14\t5\n')
# ('content', 'Cristiano_Ronaldo\t14\t16\n')
# ('content', 'Cristiano_Ronaldo\t14\t2\n')
# ('content', 'Cristiano_Ronaldo\t14\t10\n')
# ('content', 'Cristiano_Ronaldo\t14\t8\n')
# ('content', 'Cristiano_Ronaldo\t14\t9\n')
# ('content', 'Cristiano_Ronaldo\t14\t15\n')
# ('content', 'Cristiano_Ronaldo\t14\t1\n')
# ('content', 'Cristiano_Ronaldo\t14\t6\n')
# ('content', 'Cristiano_Ronaldo\t14\t12\n')
# ('content', 'Cristiano_Ronaldo\t14\t3\n')
# ('content', 'Cristiano_Ronaldo\t14\t11\n')
# ('content', 'Cristiano_Ronaldo\t13\t5\n')
# ('content', 'Cristiano_Ronaldo\t13\t16\n')
# ('content', 'Cristiano_Ronaldo\t13\t2\n')
# ('content', 'Cristiano_Ronaldo\t13\t10\n')
# ('content', 'Cristiano_Ronaldo\t13\t8\n')
# ('content', 'Cristiano_Ronaldo\t13\t9\n')
# ('content', 'Cristiano_Ronaldo\t13\t15\n')
# ('content', 'Cristiano_Ronaldo\t13\t1\n')
# ('content', 'Cristiano_Ronaldo\t13\t6\n')
# ('content', 'Cristiano_Ronaldo\t13\t12\n')
# ('content', 'Cristiano_Ronaldo\t13\t3\n')
# ('content', 'Cristiano_Ronaldo\t13\t11\n')
# ('content', 'Cristiano_Ronaldo\t5\t16\n')
# ('content', 'Cristiano_Ronaldo\t5\t2\n')
# ('content', 'Cristiano_Ronaldo\t5\t10\n')
# ('content', 'Cristiano_Ronaldo\t5\t8\n')
# ('content', 'Cristiano_Ronaldo\t5\t9\n')
# ('content', 'Cristiano_Ronaldo\t5\t15\n')
# ('content', 'Cristiano_Ronaldo\t5\t1\n')
# ('content', 'Cristiano_Ronaldo\t5\t6\n')
# ('content', 'Cristiano_Ronaldo\t5\t12\n')
# ('content', 'Cristiano_Ronaldo\t5\t3\n')
# ('content', 'Cristiano_Ronaldo\t5\t11\n')
# ('content', 'Cristiano_Ronaldo\t16\t2\n')
# ('content', 'Cristiano_Ronaldo\t16\t10\n')
# ('content', 'Cristiano_Ronaldo\t16\t8\n')
# ('content', 'Cristiano_Ronaldo\t16\t9\n')
# ('content', 'Cristiano_Ronaldo\t16\t15\n')
# ('content', 'Cristiano_Ronaldo\t16\t1\n')
# ('content', 'Cristiano_Ronaldo\t16\t6\n')
# ('content', 'Cristiano_Ronaldo\t16\t12\n')
# ('content', 'Cristiano_Ronaldo\t16\t3\n')
# ('content', 'Cristiano_Ronaldo\t16\t11\n')
# ('content', 'Cristiano_Ronaldo\t2\t10\n')
# ('content', 'Cristiano_Ronaldo\t2\t8\n')
# ('content', 'Cristiano_Ronaldo\t2\t9\n')
# ('content', 'Cristiano_Ronaldo\t2\t15\n')
# ('content', 'Cristiano_Ronaldo\t2\t1\n')
# ('content', 'Cristiano_Ronaldo\t2\t6\n')
# ('content', 'Cristiano_Ronaldo\t2\t12\n')
# ('content', 'Cristiano_Ronaldo\t2\t3\n')
# ('content', 'Cristiano_Ronaldo\t2\t11\n')
# ('content', 'Cristiano_Ronaldo\t10\t8\n')
# ('content', 'Cristiano_Ronaldo\t10\t9\n')
# ('content', 'Cristiano_Ronaldo\t10\t15\n')
# ('content', 'Cristiano_Ronaldo\t10\t1\n')
# ('content', 'Cristiano_Ronaldo\t10\t6\n')
# ('content', 'Cristiano_Ronaldo\t10\t12\n')
# ('content', 'Cristiano_Ronaldo\t10\t3\n')
# ('content', 'Cristiano_Ronaldo\t10\t11\n')
# ('content', 'Cristiano_Ronaldo\t8\t9\n')
# ('content', 'Cristiano_Ronaldo\t8\t15\n')
# ('content', 'Cristiano_Ronaldo\t8\t1\n')
# ('content', 'Cristiano_Ronaldo\t8\t6\n')
# ('content', 'Cristiano_Ronaldo\t8\t12\n')
# ('content', 'Cristiano_Ronaldo\t8\t3\n')
# ('content', 'Cristiano_Ronaldo\t8\t11\n')
# ('content', 'Cristiano_Ronaldo\t9\t15\n')
# ('content', 'Cristiano_Ronaldo\t9\t1\n')
# ('content', 'Cristiano_Ronaldo\t9\t6\n')
# ('content', 'Cristiano_Ronaldo\t9\t12\n')
# ('content', 'Cristiano_Ronaldo\t9\t3\n')
# ('content', 'Cristiano_Ronaldo\t9\t11\n')
# ('content', 'Cristiano_Ronaldo\t15\t1\n')
# ('content', 'Cristiano_Ronaldo\t15\t6\n')
# ('content', 'Cristiano_Ronaldo\t15\t12\n')
# ('content', 'Cristiano_Ronaldo\t15\t3\n')
# ('content', 'Cristiano_Ronaldo\t15\t11\n')
# ('content', 'Cristiano_Ronaldo\t1\t6\n')
# ('content', 'Cristiano_Ronaldo\t1\t12\n')
# ('content', 'Cristiano_Ronaldo\t1\t3\n')
# ('content', 'Cristiano_Ronaldo\t1\t11\n')
# ('content', 'Cristiano_Ronaldo\t6\t12\n')
# ('content', 'Cristiano_Ronaldo\t6\t3\n')
# ('content', 'Cristiano_Ronaldo\t6\t11\n')
# ('content', 'Cristiano_Ronaldo\t12\t3\n')
# ('content', 'Cristiano_Ronaldo\t12\t11\n')
# ('content', 'Cristiano_Ronaldo\t3\t11\n')
# ('name', 'David_Beckham', 'count', 30, 'randomChoice', 'David_Beckham_0015.png', 'temp', 'David_Beckham')
# ('content', 'David_Beckham\t1\t27\n')
# ('content', 'David_Beckham\t1\t8\n')
# ('content', 'David_Beckham\t1\t10\n')
# ('content', 'David_Beckham\t1\t7\n')
# ('content', 'David_Beckham\t1\t4\n')
# ('content', 'David_Beckham\t1\t2\n')
# ('content', 'David_Beckham\t1\t31\n')
# ('content', 'David_Beckham\t1\t23\n')
# ('content', 'David_Beckham\t1\t3\n')
# ('content', 'David_Beckham\t1\t29\n')
# ('content', 'David_Beckham\t1\t13\n')
# ('content', 'David_Beckham\t1\t26\n')
# ('content', 'David_Beckham\t1\t11\n')
# ('content', 'David_Beckham\t1\t6\n')
# ('content', 'David_Beckham\t1\t9\n')
# ('content', 'David_Beckham\t1\t17\n')
# ('content', 'David_Beckham\t1\t30\n')
# ('content', 'David_Beckham\t1\t14\n')
# ('content', 'David_Beckham\t1\t32\n')
# ('content', 'David_Beckham\t1\t19\n')
# ('content', 'David_Beckham\t21\t12\n')
# ('content', 'David_Beckham\t21\t15\n')
# ('content', 'David_Beckham\t5\t28\n')
# ('content', 'David_Beckham\t5\t16\n')
# ('content', 'David_Beckham\t5\t12\n')
# ('content', 'David_Beckham\t5\t15\n')
# ('content', 'David_Beckham\t28\t16\n')
# ('content', 'David_Beckham\t28\t12\n')
# ('content', 'David_Beckham\t28\t15\n')
# ('content', 'David_Beckham\t16\t12\n')
# ('content', 'David_Beckham\t16\t15\n')
# ('content', 'David_Beckham\t12\t15\n')
# ('name', 'Estefani_Lara', 'count', 30, 'randomChoice', 'Estefani_Lara_0447.png', 'temp', 'Estefani_Lara')
# ('content', 'Estefani_Lara\t687\t691\n')
# ('content', 'Estefani_Lara\t687\t590\n')
# ('content', 'Estefani_Lara\t687\t656\n')
# ('content', 'Estefani_Lara\t687\t266\n')
# ('content', 'Estefani_Lara\t687\t839\n')
# ('content', 'Estefani_Lara\t687\t740\n')
# ('content', 'Estefani_Lara\t687\t854\n')
# ('content', 'Estefani_Lara\t687\t5\n')
# ('content', 'Estefani_Lara\t687\t467\n')
# ('content', 'Estefani_Lara\t687\t50\n')
# ('content', 'Estefani_Lara\t687\t72\n')
# ('content', 'Estefani_Lara\t687\t19\n')
# ('content', 'Estefani_Lara\t687\t439\n')
# ('content', 'Estefani_Lara\t687\t247\n')
# ('content', 'Estefani_Lara\t687\t380\n')
# ('content', 'Estefani_Lara\t687\t550\n')
# ('content', 'Estefani_Lara\t687\t931\n')
# ('content', 'Estefani_Lara\t687\t702\n')
# ('content', 'Estefani_Lara\t687\t80\n')
# ('content', 'Estefani_Lara\t687\t463\n')
# ('content', 'Estefani_Lara\t687\t710\n')
# ('content', 'Estefani_Lara\t687\t15\n')
# ('content', 'Estefani_Lara\t687\t409\n')
# ('content', 'Estefani_Lara\t687\t231\n')
# ('content', 'Estefani_Lara\t687\t262\n')
# ('content', 'Estefani_Lara\t687\t344\n')
# ('content', 'Estefani_Lara\t687\t894\n')
# ('content', 'Estefani_Lara\t687\t414\n')
# ('content', 'Estefani_Lara\t687\t417\n')
# ('content', 'Estefani_Lara\t691\t590\n')
# ('content', 'Estefani_Lara\t691\t656\n')
# ('content', 'Estefani_Lara\t691\t266\n')
# ('content', 'Estefani_Lara\t691\t839\n')
# ('content', 'Estefani_Lara\t691\t740\n')
# ('content', 'Estefani_Lara\t691\t854\n')
# ('content', 'Estefani_Lara\t691\t5\n')
# ('content', 'Estefani_Lara\t691\t467\n')
# ('content', 'Estefani_Lara\t691\t50\n')
# ('content', 'Estefani_Lara\t691\t72\n')
# ('content', 'Estefani_Lara\t691\t19\n')
# ('content', 'Estefani_Lara\t691\t439\n')
# ('content', 'Estefani_Lara\t691\t247\n')
# ('content', 'Estefani_Lara\t691\t380\n')
# ('content', 'Estefani_Lara\t691\t550\n')
# ('content', 'Estefani_Lara\t691\t931\n')
# ('content', 'Estefani_Lara\t691\t702\n')
# ('content', 'Estefani_Lara\t691\t80\n')
# ('content', 'Estefani_Lara\t691\t463\n')
# ('content', 'Estefani_Lara\t691\t710\n')
# ('content', 'Estefani_Lara\t691\t15\n')
# ('content', 'Estefani_Lara\t691\t409\n')
# ('content', 'Estefani_Lara\t691\t231\n')
# ('content', 'Estefani_Lara\t691\t262\n')
# ('content', 'Estefani_Lara\t691\t344\n')
# ('content', 'Estefani_Lara\t691\t894\n')
# ('content', 'Estefani_Lara\t691\t414\n')
# ('content', 'Estefani_Lara\t691\t417\n')
# ('content', 'Estefani_Lara\t590\t656\n')
# ('content', 'Estefani_Lara\t590\t266\n')
# ('content', 'Estefani_Lara\t590\t839\n')
# ('content', 'Estefani_Lara\t590\t740\n')
# ('content', 'Estefani_Lara\t590\t854\n')
# ('content', 'Estefani_Lara\t590\t5\n')
# ('content', 'Estefani_Lara\t590\t467\n')
# ('content', 'Estefani_Lara\t590\t50\n')
# ('content', 'Estefani_Lara\t590\t72\n')
# ('content', 'Estefani_Lara\t590\t19\n')
# ('content', 'Estefani_Lara\t590\t439\n')
# ('content', 'Estefani_Lara\t590\t247\n')
# ('content', 'Estefani_Lara\t590\t380\n')
# ('content', 'Estefani_Lara\t590\t550\n')
# ('content', 'Estefani_Lara\t590\t931\n')
# ('content', 'Estefani_Lara\t590\t702\n')
# ('content', 'Estefani_Lara\t590\t80\n')
# ('content', 'Estefani_Lara\t590\t463\n')
# ('content', 'Estefani_Lara\t590\t710\n')
# ('content', 'Estefani_Lara\t590\t15\n')
# ('content', 'Estefani_Lara\t590\t409\n')
# ('content', 'Estefani_Lara\t590\t231\n')
# ('content', 'Estefani_Lara\t590\t262\n')
# ('content', 'Estefani_Lara\t590\t344\n')
# ('content', 'Estefani_Lara\t590\t894\n')
# ('content', 'Estefani_Lara\t590\t414\n')
# ('content', 'Estefani_Lara\t590\t417\n')
# ('content', 'Estefani_Lara\t656\t266\n')
# ('content', 'Estefani_Lara\t656\t839\n')
# ('content', 'Estefani_Lara\t656\t740\n')
# ('content', 'Estefani_Lara\t656\t854\n')
# ('content', 'Estefani_Lara\t656\t5\n')
# ('content', 'Estefani_Lara\t656\t467\n')
# ('content', 'Estefani_Lara\t656\t50\n')
# ('content', 'Estefani_Lara\t656\t72\n')
# ('content', 'Estefani_Lara\t656\t19\n')
# ('content', 'Estefani_Lara\t656\t439\n')
# ('content', 'Estefani_Lara\t656\t247\n')
# ('content', 'Estefani_Lara\t656\t380\n')
# ('content', 'Estefani_Lara\t656\t550\n')
# ('content', 'Estefani_Lara\t656\t931\n')
# ('content', 'Estefani_Lara\t656\t702\n')
# ('content', 'Estefani_Lara\t656\t80\n')
# ('content', 'Estefani_Lara\t656\t463\n')
# ('content', 'Estefani_Lara\t656\t710\n')
# ('content', 'Estefani_Lara\t656\t15\n')
# ('content', 'Estefani_Lara\t656\t409\n')
# ('content', 'Estefani_Lara\t656\t231\n')
# ('content', 'Estefani_Lara\t656\t262\n')
# ('content', 'Estefani_Lara\t656\t344\n')
# ('content', 'Estefani_Lara\t656\t894\n')
# ('content', 'Estefani_Lara\t656\t414\n')
# ('content', 'Estefani_Lara\t656\t417\n')
# ('content', 'Estefani_Lara\t266\t839\n')
# ('content', 'Estefani_Lara\t266\t740\n')
# ('content', 'Estefani_Lara\t266\t854\n')
# ('content', 'Estefani_Lara\t266\t5\n')
# ('content', 'Estefani_Lara\t266\t467\n')
# ('content', 'Estefani_Lara\t266\t50\n')
# ('content', 'Estefani_Lara\t266\t72\n')
# ('content', 'Estefani_Lara\t266\t19\n')
# ('content', 'Estefani_Lara\t266\t439\n')
# ('content', 'Estefani_Lara\t266\t247\n')
# ('content', 'Estefani_Lara\t266\t380\n')
# ('content', 'Estefani_Lara\t266\t550\n')
# ('content', 'Estefani_Lara\t266\t931\n')
# ('content', 'Estefani_Lara\t266\t702\n')
# ('content', 'Estefani_Lara\t266\t80\n')
# ('content', 'Estefani_Lara\t266\t463\n')
# ('content', 'Estefani_Lara\t266\t710\n')
# ('content', 'Estefani_Lara\t266\t15\n')
# ('content', 'Estefani_Lara\t266\t409\n')
# ('content', 'Estefani_Lara\t266\t231\n')
# ('content', 'Estefani_Lara\t266\t262\n')
# ('content', 'Estefani_Lara\t266\t344\n')
# ('content', 'Estefani_Lara\t266\t894\n')
# ('content', 'Estefani_Lara\t266\t414\n')
# ('content', 'Estefani_Lara\t266\t417\n')
# ('content', 'Estefani_Lara\t839\t740\n')
# ('content', 'Estefani_Lara\t839\t854\n')
# ('content', 'Estefani_Lara\t839\t5\n')
# ('content', 'Estefani_Lara\t839\t467\n')
# ('content', 'Estefani_Lara\t839\t50\n')
# ('content', 'Estefani_Lara\t839\t72\n')
# ('content', 'Estefani_Lara\t839\t19\n')
# ('content', 'Estefani_Lara\t839\t439\n')
# ('content', 'Estefani_Lara\t839\t247\n')
# ('content', 'Estefani_Lara\t839\t380\n')
# ('content', 'Estefani_Lara\t839\t550\n')
# ('content', 'Estefani_Lara\t839\t931\n')
# ('content', 'Estefani_Lara\t839\t702\n')
# ('content', 'Estefani_Lara\t839\t80\n')
# ('content', 'Estefani_Lara\t839\t463\n')
# ('content', 'Estefani_Lara\t839\t710\n')
# ('content', 'Estefani_Lara\t839\t15\n')
# ('content', 'Estefani_Lara\t839\t409\n')
# ('content', 'Estefani_Lara\t839\t231\n')
# ('content', 'Estefani_Lara\t839\t262\n')
# ('content', 'Estefani_Lara\t839\t344\n')
# ('content', 'Estefani_Lara\t839\t894\n')
# ('content', 'Estefani_Lara\t839\t414\n')
# ('content', 'Estefani_Lara\t839\t417\n')
# ('content', 'Estefani_Lara\t740\t854\n')
# ('content', 'Estefani_Lara\t740\t5\n')
# ('content', 'Estefani_Lara\t740\t467\n')
# ('content', 'Estefani_Lara\t740\t50\n')
# ('content', 'Estefani_Lara\t740\t72\n')
# ('content', 'Estefani_Lara\t740\t19\n')
# ('content', 'Estefani_Lara\t740\t439\n')
# ('content', 'Estefani_Lara\t740\t247\n')
# ('content', 'Estefani_Lara\t740\t380\n')
# ('content', 'Estefani_Lara\t740\t550\n')
# ('content', 'Estefani_Lara\t740\t931\n')
# ('content', 'Estefani_Lara\t740\t702\n')
# ('content', 'Estefani_Lara\t740\t80\n')
# ('content', 'Estefani_Lara\t740\t463\n')
# ('content', 'Estefani_Lara\t740\t710\n')
# ('content', 'Estefani_Lara\t740\t15\n')
# ('content', 'Estefani_Lara\t740\t409\n')
# ('content', 'Estefani_Lara\t740\t231\n')
# ('content', 'Estefani_Lara\t740\t262\n')
# ('content', 'Estefani_Lara\t740\t344\n')
# ('content', 'Estefani_Lara\t740\t894\n')
# ('content', 'Estefani_Lara\t740\t414\n')
# ('content', 'Estefani_Lara\t740\t417\n')
# ('content', 'Estefani_Lara\t854\t5\n')
# ('content', 'Estefani_Lara\t854\t467\n')
# ('content', 'Estefani_Lara\t854\t50\n')
# ('content', 'Estefani_Lara\t854\t72\n')
# ('content', 'Estefani_Lara\t854\t19\n')
# ('content', 'Estefani_Lara\t854\t439\n')
# ('content', 'Estefani_Lara\t854\t247\n')
# ('content', 'Estefani_Lara\t854\t380\n')
# ('content', 'Estefani_Lara\t854\t550\n')
# ('content', 'Estefani_Lara\t854\t931\n')
# ('content', 'Estefani_Lara\t854\t702\n')
# ('content', 'Estefani_Lara\t854\t80\n')
# ('content', 'Estefani_Lara\t854\t463\n')
# ('content', 'Estefani_Lara\t854\t710\n')
# ('content', 'Estefani_Lara\t854\t15\n')
# ('content', 'Estefani_Lara\t854\t409\n')
# ...
# ('content', 'Zinedine_Zidane\t994\t742\n')
# ('content', 'Zinedine_Zidane\t994\t568\n')
# ('content', 'Zinedine_Zidane\t994\t851\n')
# ('content', 'Zinedine_Zidane\t994\t807\n')
# ('content', 'Zinedine_Zidane\t994\t605\n')
# ('content', 'Zinedine_Zidane\t994\t766\n')
# ('content', 'Zinedine_Zidane\t994\t419\n')
# ('content', 'Zinedine_Zidane\t994\t606\n')
# ('content', 'Zinedine_Zidane\t994\t773\n')
# ('content', 'Zinedine_Zidane\t994\t274\n')
# ('content', 'Zinedine_Zidane\t994\t162\n')
# ('content', 'Zinedine_Zidane\t994\t686\n')
# ('content', 'Zinedine_Zidane\t994\t211\n')
# ('content', 'Zinedine_Zidane\t994\t158\n')
# ('content', 'Zinedine_Zidane\t994\t555\n')
# ('content', 'Zinedine_Zidane\t994\t344\n')
# ('content', 'Zinedine_Zidane\t994\t86\n')
# ('content', 'Zinedine_Zidane\t994\t444\n')
# ('content', 'Zinedine_Zidane\t994\t52\n')
# ('content', 'Zinedine_Zidane\t994\t972\n')
# ('content', 'Zinedine_Zidane\t994\t741\n')
# ('content', 'Zinedine_Zidane\t994\t373\n')
# ('content', 'Zinedine_Zidane\t997\t105\n')
# ('content', 'Zinedine_Zidane\t997\t332\n')
# ('content', 'Zinedine_Zidane\t997\t624\n')
# ('content', 'Zinedine_Zidane\t997\t940\n')
# ('content', 'Zinedine_Zidane\t997\t742\n')
# ('content', 'Zinedine_Zidane\t997\t568\n')
# ('content', 'Zinedine_Zidane\t997\t851\n')
# ('content', 'Zinedine_Zidane\t997\t807\n')
# ('content', 'Zinedine_Zidane\t997\t605\n')
# ('content', 'Zinedine_Zidane\t997\t766\n')
# ('content', 'Zinedine_Zidane\t997\t419\n')
# ('content', 'Zinedine_Zidane\t997\t606\n')
# ('content', 'Zinedine_Zidane\t997\t773\n')
# ('content', 'Zinedine_Zidane\t997\t274\n')
# ('content', 'Zinedine_Zidane\t997\t162\n')
# ('content', 'Zinedine_Zidane\t997\t686\n')
# ('content', 'Zinedine_Zidane\t997\t211\n')
# ('content', 'Zinedine_Zidane\t997\t158\n')
# ('content', 'Zinedine_Zidane\t997\t555\n')
# ('content', 'Zinedine_Zidane\t997\t344\n')
# ('content', 'Zinedine_Zidane\t997\t86\n')
# ('content', 'Zinedine_Zidane\t997\t444\n')
# ('content', 'Zinedine_Zidane\t997\t52\n')
# ('content', 'Zinedine_Zidane\t997\t972\n')
# ('content', 'Zinedine_Zidane\t997\t741\n')
# ('content', 'Zinedine_Zidane\t997\t373\n')
# ('content', 'Zinedine_Zidane\t105\t332\n')
# ('content', 'Zinedine_Zidane\t105\t624\n')
# ('content', 'Zinedine_Zidane\t105\t940\n')
# ('content', 'Zinedine_Zidane\t105\t742\n')
# ('content', 'Zinedine_Zidane\t105\t568\n')
# ('content', 'Zinedine_Zidane\t105\t851\n')
# ('content', 'Zinedine_Zidane\t105\t807\n')
# ('content', 'Zinedine_Zidane\t105\t605\n')
# ('content', 'Zinedine_Zidane\t105\t766\n')
# ('content', 'Zinedine_Zidane\t105\t419\n')
# ('content', 'Zinedine_Zidane\t105\t606\n')
# ('content', 'Zinedine_Zidane\t105\t773\n')
# ('content', 'Zinedine_Zidane\t105\t274\n')
# ('content', 'Zinedine_Zidane\t105\t162\n')
# ('content', 'Zinedine_Zidane\t105\t686\n')
# ('content', 'Zinedine_Zidane\t105\t211\n')
# ('content', 'Zinedine_Zidane\t105\t158\n')
# ('content', 'Zinedine_Zidane\t105\t555\n')
# ('content', 'Zinedine_Zidane\t105\t344\n')
# ('content', 'Zinedine_Zidane\t105\t86\n')
# ('content', 'Zinedine_Zidane\t105\t444\n')
# ('content', 'Zinedine_Zidane\t105\t52\n')
# ('content', 'Zinedine_Zidane\t105\t972\n')
# ('content', 'Zinedine_Zidane\t105\t741\n')
# ('content', 'Zinedine_Zidane\t105\t373\n')
# ('content', 'Zinedine_Zidane\t332\t624\n')
# ('content', 'Zinedine_Zidane\t332\t940\n')
# ('content', 'Zinedine_Zidane\t332\t742\n')
# ('content', 'Zinedine_Zidane\t332\t568\n')
# ('content', 'Zinedine_Zidane\t332\t851\n')
# ('content', 'Zinedine_Zidane\t332\t807\n')
# ('content', 'Zinedine_Zidane\t332\t605\n')
# ('content', 'Zinedine_Zidane\t332\t766\n')
# ('content', 'Zinedine_Zidane\t332\t419\n')
# ('content', 'Zinedine_Zidane\t332\t606\n')
# ('content', 'Zinedine_Zidane\t332\t773\n')
# ('content', 'Zinedine_Zidane\t332\t274\n')
# ('content', 'Zinedine_Zidane\t332\t162\n')
# ('content', 'Zinedine_Zidane\t332\t686\n')
# ('content', 'Zinedine_Zidane\t332\t211\n')
# ('content', 'Zinedine_Zidane\t332\t158\n')
# ('content', 'Zinedine_Zidane\t332\t555\n')
# ('content', 'Zinedine_Zidane\t332\t344\n')
# ('content', 'Zinedine_Zidane\t332\t86\n')
# ('content', 'Zinedine_Zidane\t332\t444\n')
# ('content', 'Zinedine_Zidane\t332\t52\n')
# ('content', 'Zinedine_Zidane\t332\t972\n')
# ('content', 'Zinedine_Zidane\t332\t741\n')
# ('content', 'Zinedine_Zidane\t332\t373\n')
# ('content', 'Zinedine_Zidane\t624\t940\n')
# ('content', 'Zinedine_Zidane\t624\t742\n')
# ('content', 'Zinedine_Zidane\t624\t568\n')
# ('content', 'Zinedine_Zidane\t624\t851\n')
# ('content', 'Zinedine_Zidane\t624\t807\n')
# ('content', 'Zinedine_Zidane\t624\t605\n')
# ('content', 'Zinedine_Zidane\t624\t766\n')
# ('content', 'Zinedine_Zidane\t624\t419\n')
# ('content', 'Zinedine_Zidane\t624\t606\n')
# ('content', 'Zinedine_Zidane\t624\t773\n')
# ('content', 'Zinedine_Zidane\t624\t274\n')
# ('content', 'Zinedine_Zidane\t624\t162\n')
# ('content', 'Zinedine_Zidane\t624\t686\n')
# ('content', 'Zinedine_Zidane\t624\t211\n')
# ('content', 'Zinedine_Zidane\t624\t158\n')
# ('content', 'Zinedine_Zidane\t624\t555\n')
# ('content', 'Zinedine_Zidane\t624\t344\n')
# ('content', 'Zinedine_Zidane\t624\t86\n')
# ('content', 'Zinedine_Zidane\t624\t444\n')
# ('content', 'Zinedine_Zidane\t624\t52\n')
# ('content', 'Zinedine_Zidane\t624\t972\n')
# ('content', 'Zinedine_Zidane\t624\t741\n')
# ('content', 'Zinedine_Zidane\t624\t373\n')
# ('content', 'Zinedine_Zidane\t940\t742\n')
# ('content', 'Zinedine_Zidane\t940\t568\n')
# ('content', 'Zinedine_Zidane\t940\t851\n')
# ('content', 'Zinedine_Zidane\t940\t807\n')
# ('content', 'Zinedine_Zidane\t940\t605\n')
# ('content', 'Zinedine_Zidane\t940\t766\n')
# ('content', 'Zinedine_Zidane\t940\t419\n')
# ('content', 'Zinedine_Zidane\t940\t606\n')
# ('content', 'Zinedine_Zidane\t940\t773\n')
# ('content', 'Zinedine_Zidane\t940\t274\n')
# ('content', 'Zinedine_Zidane\t940\t162\n')
# ('content', 'Zinedine_Zidane\t940\t686\n')
# ('content', 'Zinedine_Zidane\t940\t211\n')
# ('content', 'Zinedine_Zidane\t940\t158\n')
# ('content', 'Zinedine_Zidane\t940\t555\n')
# ('content', 'Zinedine_Zidane\t940\t344\n')
# ('content', 'Zinedine_Zidane\t940\t86\n')
# ('content', 'Zinedine_Zidane\t940\t444\n')
# ('content', 'Zinedine_Zidane\t940\t52\n')
# ('content', 'Zinedine_Zidane\t940\t972\n')
# ('content', 'Zinedine_Zidane\t940\t741\n')
# ('content', 'Zinedine_Zidane\t940\t373\n')
# ('content', 'Zinedine_Zidane\t742\t568\n')
# ('content', 'Zinedine_Zidane\t742\t851\n')
# ('content', 'Zinedine_Zidane\t742\t807\n')
# ('content', 'Zinedine_Zidane\t742\t605\n')
# ('content', 'Zinedine_Zidane\t742\t766\n')
# ('content', 'Zinedine_Zidane\t742\t419\n')
# ('content', 'Zinedine_Zidane\t742\t606\n')
# ('content', 'Zinedine_Zidane\t742\t773\n')
# ('content', 'Zinedine_Zidane\t742\t274\n')
# ('content', 'Zinedine_Zidane\t742\t162\n')
# ('content', 'Zinedine_Zidane\t742\t686\n')
# ('content', 'Zinedine_Zidane\t742\t211\n')
# ('content', 'Zinedine_Zidane\t742\t158\n')
# ('content', 'Zinedine_Zidane\t742\t555\n')
# ('content', 'Zinedine_Zidane\t742\t344\n')
# ('content', 'Zinedine_Zidane\t742\t86\n')
# ('content', 'Zinedine_Zidane\t742\t444\n')
# ('content', 'Zinedine_Zidane\t742\t52\n')
# ('content', 'Zinedine_Zidane\t742\t972\n')
# ('content', 'Zinedine_Zidane\t742\t741\n')
# ('content', 'Zinedine_Zidane\t742\t373\n')
# ('content', 'Zinedine_Zidane\t568\t851\n')
# ('content', 'Zinedine_Zidane\t568\t807\n')
# ('content', 'Zinedine_Zidane\t568\t605\n')
# ('content', 'Zinedine_Zidane\t568\t766\n')
# ('content', 'Zinedine_Zidane\t568\t419\n')
# ('content', 'Zinedine_Zidane\t568\t606\n')
# ('content', 'Zinedine_Zidane\t568\t773\n')
# ('content', 'Zinedine_Zidane\t568\t274\n')
# ('content', 'Zinedine_Zidane\t568\t162\n')
# ('content', 'Zinedine_Zidane\t568\t686\n')
# ('content', 'Zinedine_Zidane\t568\t211\n')
# ('content', 'Zinedine_Zidane\t568\t158\n')
# ('content', 'Zinedine_Zidane\t568\t555\n')
# ('content', 'Zinedine_Zidane\t568\t344\n')
# ('content', 'Zinedine_Zidane\t568\t86\n')
# ('content', 'Zinedine_Zidane\t568\t444\n')
# ('content', 'Zinedine_Zidane\t568\t52\n')
# ('content', 'Zinedine_Zidane\t568\t972\n')
# ('content', 'Zinedine_Zidane\t568\t741\n')
# ('content', 'Zinedine_Zidane\t568\t373\n')
# ('content', 'Zinedine_Zidane\t851\t807\n')
# ('content', 'Zinedine_Zidane\t851\t605\n')
# ('content', 'Zinedine_Zidane\t851\t766\n')
# ('content', 'Zinedine_Zidane\t851\t419\n')
# ('content', 'Zinedine_Zidane\t851\t606\n')
# ('content', 'Zinedine_Zidane\t851\t773\n')
# ('content', 'Zinedine_Zidane\t851\t274\n')
# ('content', 'Zinedine_Zidane\t851\t162\n')
# ('content', 'Zinedine_Zidane\t851\t686\n')
# ('content', 'Zinedine_Zidane\t851\t211\n')
# ('content', 'Zinedine_Zidane\t851\t158\n')
# ('content', 'Zinedine_Zidane\t851\t555\n')
# ('content', 'Zinedine_Zidane\t851\t344\n')
# ('content', 'Zinedine_Zidane\t851\t86\n')
# ('content', 'Zinedine_Zidane\t851\t444\n')
# ('content', 'Zinedine_Zidane\t851\t52\n')
# ('content', 'Zinedine_Zidane\t851\t972\n')
# ('content', 'Zinedine_Zidane\t851\t741\n')
# ('content', 'Zinedine_Zidane\t851\t373\n')
# ('content', 'Zinedine_Zidane\t807\t605\n')
# ('content', 'Zinedine_Zidane\t807\t766\n')
# ('content', 'Zinedine_Zidane\t807\t419\n')
# ('content', 'Zinedine_Zidane\t807\t606\n')
# ('content', 'Zinedine_Zidane\t807\t773\n')
# ('content', 'Zinedine_Zidane\t807\t274\n')
# ('content', 'Zinedine_Zidane\t807\t162\n')
# ('content', 'Zinedine_Zidane\t807\t686\n')
# ('content', 'Zinedine_Zidane\t807\t211\n')
# ('content', 'Zinedine_Zidane\t807\t158\n')
# ('content', 'Zinedine_Zidane\t807\t555\n')
# ('content', 'Zinedine_Zidane\t807\t344\n')
# ('content', 'Zinedine_Zidane\t807\t86\n')
# ('content', 'Zinedine_Zidane\t807\t444\n')
# ('content', 'Zinedine_Zidane\t807\t52\n')
# ('content', 'Zinedine_Zidane\t807\t972\n')
# ('content', 'Zinedine_Zidane\t807\t741\n')
# ('content', 'Zinedine_Zidane\t807\t373\n')
# ('content', 'Zinedine_Zidane\t605\t766\n')
# ('content', 'Zinedine_Zidane\t605\t419\n')
# ('content', 'Zinedine_Zidane\t605\t606\n')
# ('content', 'Zinedine_Zidane\t605\t773\n')
# ('content', 'Zinedine_Zidane\t605\t274\n')
# ('content', 'Zinedine_Zidane\t605\t162\n')
# ('content', 'Zinedine_Zidane\t605\t686\n')
# ('content', 'Zinedine_Zidane\t605\t211\n')
# ('content', 'Zinedine_Zidane\t605\t158\n')
# ('content', 'Zinedine_Zidane\t605\t555\n')
# ('content', 'Zinedine_Zidane\t605\t344\n')
# ('content', 'Zinedine_Zidane\t605\t86\n')
# ('content', 'Zinedine_Zidane\t605\t444\n')
# ('content', 'Zinedine_Zidane\t605\t52\n')
# ('content', 'Zinedine_Zidane\t605\t972\n')
# ('content', 'Zinedine_Zidane\t605\t741\n')
# ('content', 'Zinedine_Zidane\t605\t373\n')
# ('content', 'Zinedine_Zidane\t766\t419\n')
# ('content', 'Zinedine_Zidane\t766\t606\n')
# ('content', 'Zinedine_Zidane\t766\t773\n')
# ('content', 'Zinedine_Zidane\t766\t274\n')
# ('content', 'Zinedine_Zidane\t766\t162\n')
# ('content', 'Zinedine_Zidane\t766\t686\n')
# ('content', 'Zinedine_Zidane\t766\t211\n')
# ('content', 'Zinedine_Zidane\t766\t158\n')
# ('content', 'Zinedine_Zidane\t766\t555\n')
# ('content', 'Zinedine_Zidane\t766\t344\n')
# ('content', 'Zinedine_Zidane\t766\t86\n')
# ('content', 'Zinedine_Zidane\t766\t444\n')
# ('content', 'Zinedine_Zidane\t766\t52\n')
# ('content', 'Zinedine_Zidane\t766\t972\n')
# ('content', 'Zinedine_Zidane\t766\t741\n')
# ('content', 'Zinedine_Zidane\t766\t373\n')
# ('content', 'Zinedine_Zidane\t419\t606\n')
# ('content', 'Zinedine_Zidane\t419\t773\n')
# ('content', 'Zinedine_Zidane\t419\t274\n')
# ('content', 'Zinedine_Zidane\t419\t162\n')
# ('content', 'Zinedine_Zidane\t419\t686\n')
# ('content', 'Zinedine_Zidane\t419\t211\n')
# ('content', 'Zinedine_Zidane\t419\t158\n')
# ('content', 'Zinedine_Zidane\t419\t555\n')
# ('content', 'Zinedine_Zidane\t419\t344\n')
# ('content', 'Zinedine_Zidane\t419\t86\n')
# ('content', 'Zinedine_Zidane\t419\t444\n')
# ('content', 'Zinedine_Zidane\t419\t52\n')
# ('content', 'Zinedine_Zidane\t419\t972\n')
# ('content', 'Zinedine_Zidane\t419\t741\n')
# ('content', 'Zinedine_Zidane\t419\t373\n')
# ('content', 'Zinedine_Zidane\t606\t773\n')
# ('content', 'Zinedine_Zidane\t606\t274\n')
# ('content', 'Zinedine_Zidane\t606\t162\n')
# ('content', 'Zinedine_Zidane\t606\t686\n')
# ('content', 'Zinedine_Zidane\t606\t211\n')
# ('content', 'Zinedine_Zidane\t606\t158\n')
# ('content', 'Zinedine_Zidane\t606\t555\n')
# ('content', 'Zinedine_Zidane\t606\t344\n')
# ('content', 'Zinedine_Zidane\t606\t86\n')
# ('content', 'Zinedine_Zidane\t606\t444\n')
# ('content', 'Zinedine_Zidane\t606\t52\n')
# ('content', 'Zinedine_Zidane\t606\t972\n')
# ('content', 'Zinedine_Zidane\t606\t741\n')
# ('content', 'Zinedine_Zidane\t606\t373\n')
# ('content', 'Zinedine_Zidane\t773\t274\n')
# ('content', 'Zinedine_Zidane\t773\t162\n')
# ('content', 'Zinedine_Zidane\t773\t686\n')
# ('content', 'Zinedine_Zidane\t773\t211\n')
# ('content', 'Zinedine_Zidane\t773\t158\n')
# ('content', 'Zinedine_Zidane\t773\t555\n')
# ('content', 'Zinedine_Zidane\t773\t344\n')
# ('content', 'Zinedine_Zidane\t773\t86\n')
# ('content', 'Zinedine_Zidane\t773\t444\n')
# ('content', 'Zinedine_Zidane\t773\t52\n')
# ('content', 'Zinedine_Zidane\t773\t972\n')
# ('content', 'Zinedine_Zidane\t773\t741\n')
# ('content', 'Zinedine_Zidane\t773\t373\n')
# ('content', 'Zinedine_Zidane\t274\t162\n')
# ('content', 'Zinedine_Zidane\t274\t686\n')
# ('content', 'Zinedine_Zidane\t274\t211\n')
# ('content', 'Zinedine_Zidane\t274\t158\n')
# ('content', 'Zinedine_Zidane\t274\t555\n')
# ('content', 'Zinedine_Zidane\t274\t344\n')
# ('content', 'Zinedine_Zidane\t274\t86\n')
# ('content', 'Zinedine_Zidane\t274\t444\n')
# ('content', 'Zinedine_Zidane\t274\t52\n')
# ('content', 'Zinedine_Zidane\t274\t972\n')
# ('content', 'Zinedine_Zidane\t274\t741\n')
# ('content', 'Zinedine_Zidane\t274\t373\n')
# ('content', 'Zinedine_Zidane\t162\t686\n')
# ('content', 'Zinedine_Zidane\t162\t211\n')
# ('content', 'Zinedine_Zidane\t162\t158\n')
# ('content', 'Zinedine_Zidane\t162\t555\n')
# ('content', 'Zinedine_Zidane\t162\t344\n')
# ('content', 'Zinedine_Zidane\t162\t86\n')
# ('content', 'Zinedine_Zidane\t162\t444\n')
# ('content', 'Zinedine_Zidane\t162\t52\n')
# ('content', 'Zinedine_Zidane\t162\t972\n')
# ('content', 'Zinedine_Zidane\t162\t741\n')
# ('content', 'Zinedine_Zidane\t162\t373\n')
# ('content', 'Zinedine_Zidane\t686\t211\n')
# ('content', 'Zinedine_Zidane\t686\t158\n')
# ('content', 'Zinedine_Zidane\t686\t555\n')
# ('content', 'Zinedine_Zidane\t686\t344\n')
# ('content', 'Zinedine_Zidane\t686\t86\n')
# ('content', 'Zinedine_Zidane\t686\t444\n')
# ('content', 'Zinedine_Zidane\t686\t52\n')
# ('content', 'Zinedine_Zidane\t686\t972\n')
# ('content', 'Zinedine_Zidane\t686\t741\n')
# ('content', 'Zinedine_Zidane\t686\t373\n')
# ('content', 'Zinedine_Zidane\t211\t158\n')
# ('content', 'Zinedine_Zidane\t211\t555\n')
# ('content', 'Zinedine_Zidane\t211\t344\n')
# ('content', 'Zinedine_Zidane\t211\t86\n')
# ('content', 'Zinedine_Zidane\t211\t444\n')
# ('content', 'Zinedine_Zidane\t211\t52\n')
# ('content', 'Zinedine_Zidane\t211\t972\n')
# ('content', 'Zinedine_Zidane\t211\t741\n')
# ('content', 'Zinedine_Zidane\t211\t373\n')
# ('content', 'Zinedine_Zidane\t158\t555\n')
# ('content', 'Zinedine_Zidane\t158\t344\n')
# ('content', 'Zinedine_Zidane\t158\t86\n')
# ('content', 'Zinedine_Zidane\t158\t444\n')
# ('content', 'Zinedine_Zidane\t158\t52\n')
# ('content', 'Zinedine_Zidane\t158\t972\n')
# ('content', 'Zinedine_Zidane\t158\t741\n')
# ('content', 'Zinedine_Zidane\t158\t373\n')
# ('content', 'Zinedine_Zidane\t555\t344\n')
# ('content', 'Zinedine_Zidane\t555\t86\n')
# ('content', 'Zinedine_Zidane\t555\t444\n')
# ('content', 'Zinedine_Zidane\t555\t52\n')
# ('content', 'Zinedine_Zidane\t555\t972\n')
# ('content', 'Zinedine_Zidane\t555\t741\n')
# ('content', 'Zinedine_Zidane\t555\t373\n')
# ('content', 'Zinedine_Zidane\t344\t86\n')
# ('content', 'Zinedine_Zidane\t344\t444\n')
# ('content', 'Zinedine_Zidane\t344\t52\n')
# ('content', 'Zinedine_Zidane\t344\t972\n')
# ('content', 'Zinedine_Zidane\t344\t741\n')
# ('content', 'Zinedine_Zidane\t344\t373\n')
# ('content', 'Zinedine_Zidane\t86\t444\n')
# ('content', 'Zinedine_Zidane\t86\t52\n')
# ('content', 'Zinedine_Zidane\t86\t972\n')
# ('content', 'Zinedine_Zidane\t86\t741\n')
# ('content', 'Zinedine_Zidane\t86\t373\n')
# ('content', 'Zinedine_Zidane\t444\t52\n')
# ('content', 'Zinedine_Zidane\t444\t972\n')
# ('content', 'Zinedine_Zidane\t444\t741\n')
# ('content', 'Zinedine_Zidane\t444\t373\n')
# ('content', 'Zinedine_Zidane\t52\t972\n')
# ('content', 'Zinedine_Zidane\t52\t741\n')
# ('content', 'Zinedine_Zidane\t52\t373\n')
# ('content', 'Zinedine_Zidane\t972\t741\n')
# ('content', 'Zinedine_Zidane\t972\t373\n')
# ('content', 'Zinedine_Zidane\t741\t373\n')

# %% [markdown]
# References
#
# https://github.com/davidsandberg/facenet/issues/682
# http://vis-www.cs.umass.edu/lfw/README.txt
