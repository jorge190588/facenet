# %%
import os
import random


def createPairs(totalPairs):
    result = []
    for i in range(0, totalPairs-1):
        for y in range(i+1, totalPairs):
            #print str(i)+'-'+str(y)
            result.append([i,y])
    
    return result

def getFolders(baseDir):
    folders = [name for name in os.listdir(baseDir) if name.find(".txt") == -1]
    #print folders
    return folders

baseDir = "output/"
separate = "_0"
folders = getFolders(baseDir)
filePath = "/notebooks/data/pairs200.txt"

def pairs():
    for name in folders:    
        path, dirs, files = next(os.walk(baseDir+name))
        file_count = len(files)
        print('name',name,'count',file_count)
        if file_count>200:
            file_count=200
            
        if(file_count>0):
            a = []
            for file in os.listdir(baseDir + name):
                a.append(file)

            with open(filePath,"a") as f:
                pair_two_list = createPairs(file_count)
                randomChoice = random.choice(a)
                print randomChoice
                temp = random.choice(a).split(separate)[0] # This line may vary depending on how your images are named.
                for l1 in pair_two_list:
                    n0 = a[l1[0]].split(separate)[1].lstrip("0").rstrip(".png")
                    n1 = a[l1[1]].split(separate)[1].lstrip("0").rstrip(".png")
                    f.write(temp + "\t" + n0 + "\t" + n1 + "\n")

def shuffle(): 
    for i,name in enumerate(folders):
        remaining = folders

        del remaining[i] # deletes the file from the list, so that it is not chosen again
        other_dir = random.choice(remaining)

        with open(filePath,"a") as f:
            flag=1
            for i in range(1):
                file1 = random.choice(os.listdir(baseDir + name))
                file2 = random.choice(os.listdir(baseDir+ other_dir))
                content = name + "\t" + file1.split(separate)[1].lstrip("0").rstrip(".png") + "\t" + other_dir + "\t" + file2.split(separate)[1].lstrip("0").rstrip(".png") + "\n"
                f.write(content)

# %%
print getFolders(baseDir)
pairs()
shuffle()
# Out:
# ['Xavi_Hernadez', 'Cristiano_Ronaldo', 'Pep_Guardiola', 'Estefani_Lara', 'Luis_Figo', 'Jorge_Santos', 'Raul_Gonzalez', 'Iker_Casillas', 'Neymar_daSilva', 'Luca_Modric', 'Gareth_Bale', 'Camila_Santos', 'David_Beckham', 'Marcelo_Vieira', 'Ronaldinho_Moreira', 'Sergio_Ramos', 'Zinedine_Zidane', 'Michael_Jackson', 'Leonel_Messi', 'Jose_Mourinho', 'Marco_Asensio']
# ('name', 'Xavi_Hernadez', 'count', 878)
# Xavi_Hernadez_0587.png
# ('name', 'Cristiano_Ronaldo', 'count', 16)
# Cristiano_Ronaldo_0016.png
# ('name', 'Pep_Guardiola', 'count', 999)
# Pep_Guardiola_0764.png
# ('name', 'Estefani_Lara', 'count', 997)
# Estefani_Lara_0298.png
# ('name', 'Luis_Figo', 'count', 987)
# Luis_Figo_0855.png
# ('name', 'Jorge_Santos', 'count', 998)
# Jorge_Santos_0616.png
# ('name', 'Raul_Gonzalez', 'count', 999)
# Raul_Gonzalez_0222.png
# ('name', 'Iker_Casillas', 'count', 660)
# Iker_Casillas_0634.png
# ('name', 'Neymar_daSilva', 'count', 999)
# Neymar_daSilva_0305.png
# ('name', 'Luca_Modric', 'count', 999)
# Luca_Modric_0001.png
# ('name', 'Gareth_Bale', 'count', 999)
# Gareth_Bale_0567.png
# ('name', 'Camila_Santos', 'count', 940)
# Camila_Santos_0331.png
# ('name', 'David_Beckham', 'count', 31)
# David_Beckham_0028.png
# ('name', 'Marcelo_Vieira', 'count', 998)
# Marcelo_Vieira_0865.png
# ('name', 'Ronaldinho_Moreira', 'count', 999)
# Ronaldinho_Moreira_0343.png
# ('name', 'Sergio_Ramos', 'count', 999)
# Sergio_Ramos_0556.png
# ('name', 'Zinedine_Zidane', 'count', 999)
# Zinedine_Zidane_0265.png
# ('name', 'Michael_Jackson', 'count', 12)
# Michael_Jackson_0009.png
# ('name', 'Leonel_Messi', 'count', 995)
# Leonel_Messi_0784.png
# ('name', 'Jose_Mourinho', 'count', 999)
# Jose_Mourinho_0035.png
# ('name', 'Marco_Asensio', 'count', 999)
# Marco_Asensio_0513.png

# %% [markdown]
# References
#
# https://github.com/davidsandberg/facenet/issues/682
# http://vis-www.cs.umass.edu/lfw/README.txt
